# %%
# !pip install tensorflow -q

# %%
from tensorflow import keras
from sklearn.linear_model import Perceptron

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
# get MNIST handwritten digits image training and test data
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# normalize data (each pixel starts as int 0-255; we want it to be a float between 0 and 1)
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
# show sample images

for i in range(30,35):
    plt.figure()
    plt.matshow(x_train[i])
    plt.title(f'Label: {y_train[i]}')

# %%
# let's train a perceptron on these images

# first, we need to flatten our images (from 2d into a 1d array)
x_train_flat = x_train.reshape(x_train.shape[0], -1)
x_test_flat = x_test.reshape(x_test.shape[0], -1)

# create and train the perceptron
perceptron = Perceptron()
perceptron.fit(x_train_flat, y_train)

# print train and test accuracy scores
print(f"Training data score: {perceptron.score(x_train_flat, y_train)}")
print(f"Training data score: {perceptron.score(x_test_flat, y_test)}")
# Out:
# Training data score: 0.8853833333333333
# Training data score: 0.8805

# %%
# let's see the confusion matrix
plt.matshow( confusion_matrix( perceptron.predict(x_test_flat), y_test ) )

# %%
# let's use tensorflow keras library to build a 10 perceptron model
#  Dense layers are standard fully-interconnected neural network layers
model = keras.models.Sequential([
    keras.layers.Dense(10, activation='softmax') # output layer
])

# we'll use sparse_categorical_crossentropy as the loss function
LOSS_FN = keras.losses.sparse_categorical_crossentropy

# compile the model with standard backprop training algorithm called 'adam'
model.compile(optimizer='adam',loss=LOSS_FN,metrics=['accuracy'])

# train on training data, and validate on test data
# we'll train for 5 epochs
model.fit(x_train_flat, y_train, epochs=5, validation_data=(x_test_flat, y_test))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4703 - accuracy: 0.8774 - val_loss: 0.3054 - val_accuracy: 0.9155
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3042 - accuracy: 0.9151 - val_loss: 0.2835 - val_accuracy: 0.9213
# Epoch 3/5
# 1875/1875 [==============================] - 2s 993us/step - loss: 0.2835 - accuracy: 0.9204 - val_loss: 0.2755 - val_accuracy: 0.9237
# Epoch 4/5
# 1875/1875 [==============================] - 2s 998us/step - loss: 0.2733 - accuracy: 0.9235 - val_loss: 0.2719 - val_accuracy: 0.9233
# Epoch 5/5
# 1875/1875 [==============================] - 2s 983us/step - loss: 0.2664 - accuracy: 0.9261 - val_loss: 0.2683 - val_accuracy: 0.9234

# %%
# let's check the confusion matrix
plt.matshow( confusion_matrix( model.predict(x_test_flat).argmax(1), y_test ) )
# Out:
# 313/313 [==============================] - 0s 754us/step

# %%
# let's build a whole bunch of models to compare
modelNames = [
    '1d',
    '2d',
    '3d',
    '1c1d',
    '1c2d',
    '2c2d',
]

# in all models we'll have the same number of nodes per hidden layer
NODES_PER_HIDDEN_LAYER = 64

models = [
    # just the output layer
    keras.models.Sequential([
        keras.layers.Flatten(input_shape=(28, 28)),
        keras.layers.Dense(10, activation='softmax') # output layer
    ]),
    # 1 hidden layer
    keras.models.Sequential([
        keras.layers.Flatten(input_shape=(28, 28)),
        keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),  # hidden layer 1
        keras.layers.Dense(10, activation='softmax') # output layer
    ]),
    # 2 hidden layers
    keras.models.Sequential([
        keras.layers.Flatten(input_shape=(28, 28)),
        keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),  # hidden layer 1
        keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),   # hidden layer 2
        keras.layers.Dense(10, activation='softmax') # output layer
    ]),
    # 1 convolutional layer
    keras.models.Sequential([
        keras.Input(shape=(28,28,1)),
        keras.layers.Conv2D(NODES_PER_HIDDEN_LAYER, kernel_size=(3, 3), activation="relu"),  #convolutional layer 1
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")  # output layer
    ]),
    # 1 convolutional layer and 1 hidden dense layer
    keras.models.Sequential([
        keras.Input(shape=(28,28,1)),
        keras.layers.Conv2D(NODES_PER_HIDDEN_LAYER, kernel_size=(3, 3), activation="relu"),  #convolutional layer 1
        keras.layers.Flatten(),
        keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),  # hidden layer 1
        keras.layers.Dense(10, activation="softmax")  # output layer
    ]),
    # 2 convolutional layers and 1 hidden dense layer
    keras.models.Sequential([
        keras.Input(shape=(28,28,1)),
        keras.layers.Conv2D(NODES_PER_HIDDEN_LAYER, kernel_size=(3, 3), activation="relu"),  #convolutional layer 1
        keras.layers.Conv2D(NODES_PER_HIDDEN_LAYER, kernel_size=(3, 3), activation="relu"),  #convolutional layer 2
        keras.layers.Flatten(),
        keras.layers.Dense(NODES_PER_HIDDEN_LAYER, activation='relu'),  # hidden layer 1
        keras.layers.Dense(10, activation="softmax")  # output layer
    ])
]

# %%
# compile all models
for model in models:
    model.compile(optimizer='adam',loss=LOSS_FN,metrics=['accuracy'])

# %%
TRAINING_EPOCHS = 5

# train all models
for model, name in zip(models, modelNames):
    print(f'training model {name}')
    model.fit(x_train, y_train, epochs=TRAINING_EPOCHS)
# Out:
# training model 1d
# Epoch 1/5
# 1875/1875 [==============================] - 2s 979us/step - loss: 0.4677 - accuracy: 0.8777
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3043 - accuracy: 0.9149
# Epoch 3/5
# 1875/1875 [==============================] - 2s 956us/step - loss: 0.2834 - accuracy: 0.9205
# Epoch 4/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2735 - accuracy: 0.9238
# Epoch 5/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2670 - accuracy: 0.9254
# training model 2d
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3007 - accuracy: 0.9156
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1470 - accuracy: 0.9570
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1066 - accuracy: 0.9685
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0832 - accuracy: 0.9749
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0683 - accuracy: 0.9794
# training model 3d
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2764 - accuracy: 0.9192
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1264 - accuracy: 0.9614
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0915 - accuracy: 0.9718
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0725 - accuracy: 0.9771
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0594 - accuracy: 0.9809
# training model 1c1d
# Epoch 1/5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1520 - accuracy: 0.9552
# Epoch 2/5
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0612 - accuracy: 0.9815
# Epoch 3/5
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0415 - accuracy: 0.9870
# Epoch 4/5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0290 - accuracy: 0.9910
# Epoch 5/5
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0208 - accuracy: 0.9933
# training model 1c2d
# Epoch 1/5
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.1444 - accuracy: 0.9561
# Epoch 2/5
# 1875/1875 [==============================] - 55s 29ms/step - loss: 0.0476 - accuracy: 0.9853
# Epoch 3/5
# 1875/1875 [==============================] - 54s 29ms/step - loss: 0.0276 - accuracy: 0.9912
# Epoch 4/5
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.0170 - accuracy: 0.9943
# Epoch 5/5
# 1875/1875 [==============================] - 51s 27ms/step - loss: 0.0128 - accuracy: 0.9957
# training model 2c2d
# Epoch 1/5
# 1875/1875 [==============================] - 100s 53ms/step - loss: 0.1207 - accuracy: 0.9634
# Epoch 2/5
# 1875/1875 [==============================] - 99s 53ms/step - loss: 0.0393 - accuracy: 0.9877
# Epoch 3/5
# 1875/1875 [==============================] - 101s 54ms/step - loss: 0.0247 - accuracy: 0.9919
# Epoch 4/5
# 1875/1875 [==============================] - 99s 53ms/step - loss: 0.0152 - accuracy: 0.9951
# Epoch 5/5
# 1875/1875 [==============================] - 100s 54ms/step - loss: 0.0101 - accuracy: 0.9964

# %%
# get all model accuracy scores on test data
scores = [model.evaluate(x_test,y_test)[1] for model in models]
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2691 - accuracy: 0.9256
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0908 - accuracy: 0.9725
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0834 - accuracy: 0.9741
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0730 - accuracy: 0.9793
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0552 - accuracy: 0.9840
# 313/313 [==============================] - 4s 11ms/step - loss: 0.0481 - accuracy: 0.9871

# %%
# let's also add the perceptron score to our accuracy scores list
modelNames.insert(0, 'perceptron')
scores.insert(0, perceptron.score(x_test_flat, y_test) )

# print all models and scores
for name,score in zip(modelNames,scores):
    print(name, score)
# Out:
# perceptron 0.8805
# 1d 0.925599992275238
# 2d 0.9725000262260437
# 3d 0.9740999937057495
# 1c1d 0.9793000221252441
# 1c2d 0.984000027179718
# 2c2d 0.9871000051498413

# %%
# display as a bar chart
plt.bar(modelNames,scores)
plt.ylim(0.8, 1.0)
plt.show()
