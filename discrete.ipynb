# %%
# !pip install numpy
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/155.5 kB ? eta -:--:--
#      -------------------------------------  153.6/155.5 kB 4.5 MB/s eta 0:00:01
#      -------------------------------------- 155.5/155.5 kB 4.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    --------- ------------------------------ 1.9/7.6 MB 61.1 MB/s eta 0:00:01
#    ------------------------ --------------- 4.8/7.6 MB 51.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 61.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/486.7 kB ? eta -:--:--
#    --------------------------------------- 486.7/486.7 kB 29.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 68.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values
x = np.linspace(-2, 2, 100)  # Adjust the range and number of points as needed

# Calculate y values
y = np.exp(x)

# Create the plot
plt.plot(x, y, label='$e^x$')
plt.axhline(0, color='k', linewidth=1.2)  # Add a dark horizontal line at y=0
plt.axvline(0, color='k', linewidth=1.2)  # Add a dark vertical line at x=0

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of $y = e^x$')
plt.grid(True)
plt.legend()

# Display the plot
plt.show() 
#programmed by Khagendra Khatri

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values
x = np.linspace(0, 5, 100)  # Adjust the range and number of points as needed

# Calculate y values
y = np.exp(-x)

# Create the plot
plt.plot(x, y, label='$e^{-x}$')
plt.axhline(0, color='k', linewidth=1.2)  # Add a dark horizontal line at y=0
plt.axvline(0, color='k', linewidth=1.2)  # Add a dark vertical line at x=0

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of $y = e^{-x}$')
plt.grid(True)
plt.legend()

# Display the plot
plt.show() #programmed by Khagendra Khatri

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set the value of 'a' (choose any non-zero value)
a = 2.0

# Generate x values
x = np.linspace(-2, 2, 100)  # Adjust the range and number of points as needed

# Calculate y values
y = a**x

# Create the plot
plt.plot(x, y, label=f'$y = a^x$')
plt.axhline(0, color='k', linewidth=0.8)  # Add a dark horizontal line at y=0
plt.axvline(0, color='k', linewidth=0.8)  # Add a dark vertical line at x=0

plt.xlabel('x')
plt.ylabel('y')
plt.title(f'Plot of $y = a^x$')
plt.grid(True)
plt.legend()

# Display the plot
plt.show() #programmed by Khagendra Khatri

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set the value of 'a' (choose any non-zero value)
a = 2.0

# Generate x values
x = np.linspace(-2, 2, 100)  # Adjust the range and number of points as needed

# Calculate y values
y = a**(-x)

# Create the plot
plt.plot(x, y, label=f'$y = a^{{-x}}$')
plt.axhline(0, color='k', linewidth=0.8)  # Add a dark horizontal line at y=0
plt.axvline(0, color='k', linewidth=0.8)  # Add a dark vertical line at x=0

plt.xlabel('x')
plt.ylabel('y')
plt.title(f'Plot of $y = a^{{-x}}$')
plt.grid(True)
plt.legend()

# Display the plot
plt.show() #programmed by Khagendra Khatri

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values (ensure x is positive)
x = np.linspace(0.01, 5, 100)  # Adjust the range and number of points as needed, avoiding x=0

# Calculate y values
y = np.log(x) / np.log(3)  # Calculate the base-3 logarithm

# Create the plot
plt.plot(x, y, label='$\log_b(x)$')
plt.axhline(0, color='k', linewidth=0.8)  # Add a dark horizontal line at y=0
plt.axvline(0, color='k', linewidth=0.8)  # Add a dark vertical line at x=0

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of $y = \log_b(x)$')
plt.grid(True)
plt.legend()

# Display the plot
plt.show() #programmed by Khagendra Khatri
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\l'
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# <>:11: SyntaxWarning: invalid escape sequence '\l'
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\Khage\AppData\Local\Temp\ipykernel_22552\4209658239.py:11: SyntaxWarning: invalid escape sequence '\l'
#   plt.plot(x, y, label='$\log_b(x)$')
# C:\Users\Khage\AppData\Local\Temp\ipykernel_22552\4209658239.py:17: SyntaxWarning: invalid escape sequence '\l'
#   plt.title('Plot of $y = \log_b(x)$')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values
x = np.linspace(0.01, 5, 100)  # Adjust the range and number of points as needed, avoiding x=0

# Calculate y values
y = np.log(x)

# Create the plot
plt.plot(x, y, label='$\ln(x)$')
plt.axhline(0, color='k', linewidth=1.2)  # Add a dark horizontal line at y=0
plt.axvline(0, color='k', linewidth=1.2)  # Add a dark vertical line at x=0

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of $y = \ln(x)$')
plt.grid(True)
plt.legend()

# Display the plot
plt.show() #programmed by Khagendra Khatri
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\l'
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# <>:11: SyntaxWarning: invalid escape sequence '\l'
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\Khage\AppData\Local\Temp\ipykernel_31612\4167498628.py:11: SyntaxWarning: invalid escape sequence '\l'
#   plt.plot(x, y, label='$\ln(x)$')
# C:\Users\Khage\AppData\Local\Temp\ipykernel_31612\4167498628.py:17: SyntaxWarning: invalid escape sequence '\l'
#   plt.title('Plot of $y = \ln(x)$')
